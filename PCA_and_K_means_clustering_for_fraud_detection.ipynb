# %% [markdown]
# ## PCA and Kmeans For Fraud and Anomaly Detection

# %% [markdown]
# **Import the relevant libraries**

# %%
import pandas as pd
import numpy as np
import io 
import statsmodels.api as sm

# %% [markdown]
# **Import the two datasets**

# %%
raw_data1 = pd.read_csv('/data/OBGYN_practice_dataset.csv')
OBGYN_category_v2 = pd.read_csv('/data/OBGYN_categories_v2.csv')

# %% [markdown]
# **Merge the two dataframes in order to get the alternative categorization**

# %%
merged = pd.merge(raw_data1, OBGYN_category_v2, on="procedure_concept_id")

# %% [markdown]
# **Inspect the dataset**

# %%
merged
# Out:
#        person_id procedure_date  procedure_concept_id        concept_name_x  \
# 0          11248         8/3/20               2004407  Amputation of cervix
# 1          11874         4/6/20               2004407  Amputation of cervix
# 2          12745       12/20/19               2004407  Amputation of cervix
# 3          13133        7/29/19               2004407  Amputation of cervix
# 4          13844        8/31/20               2004407  Amputation of cervix
# ...          ...            ...                   ...                   ...
# 52188      19298        9/26/19              45890386   Abortion Procedures
# 52189      19406        1/18/20              45890386   Abortion Procedures
# 52190      19435        8/26/20              45890386   Abortion Procedures
# 52191      19656        4/30/20              45890386   Abortion Procedures
# 52192      19678        8/27/20              45890386   Abortion Procedures
#
#        amount  total_paid  provider_id                    provider_name  \
# 0           1         839        45192  Baptist Health & Medical Center
# 1           1         839        52356              Boudica Female Care
# 2           1         839        24023                dr. Mariano & Co.
# 3           1         839        24023                dr. Mariano & Co.
# 4           1         839        45192  Baptist Health & Medical Center
# ...       ...         ...          ...                              ...
# 52188       1        1129        45192  Baptist Health & Medical Center
# 52189       1        1129        45192  Baptist Health & Medical Center
# 52190       1        1129         4823   East Westfield Health Services
# 52191       1        1129        45192  Baptist Health & Medical Center
# 52192       1        1129         4823   East Westfield Health Services
#
#       category according to domain expert  \
# 0                               Procedure
# 1                               Procedure
# 2                               Procedure
# 3                               Procedure
# 4                               Procedure
# ...                                   ...
# 52188                           Procedure
# 52189                           Procedure
# 52190                           Procedure
# 52191                           Procedure
# 52192                           Procedure
#
#       category according to process mining        concept_name_y
# 0                              Gynaecology  Amputation of cervix
# 1                              Gynaecology  Amputation of cervix
# 2                              Gynaecology  Amputation of cervix
# 3                              Gynaecology  Amputation of cervix
# 4                              Gynaecology  Amputation of cervix
# ...                                    ...                   ...
# 52188                          Gynaecology   Abortion Procedures
# 52189                          Gynaecology   Abortion Procedures
# 52190                          Gynaecology   Abortion Procedures
# 52191                          Gynaecology   Abortion Procedures
# 52192                          Gynaecology   Abortion Procedures
#
# [52193 rows x 11 columns]

# %% [markdown]
# **Create a pivot table**

# %%
pivot = pd.pivot_table(merged, values = 'amount', index=['person_id'], 
                       columns = 'category according to process mining',aggfunc=np.sum).reset_index()

# %% [markdown]
# **Inspect the pivot table**

# %%
pivot
# Out:
# category according to process mining  person_id  Consultation  Delivery  \
# 0                                         10429           4.0       NaN
# 1                                         10430          10.0       1.0
# 2                                         10431           9.0       1.0
# 3                                         10432           6.0       NaN
# 4                                         10433           1.0       NaN
# ...                                         ...           ...       ...
# 9258                                      19688           NaN       1.0
# 9259                                      19689           2.0       NaN
# 9260                                      19690          10.0       1.0
# 9261                                      19691           1.0       NaN
# 9262                                      19692           1.0       NaN
#
# category according to process mining  Gynaecology  Obstetrics
# 0                                             3.0         NaN
# 1                                             NaN         8.0
# 2                                             NaN         7.0
# 3                                             NaN         6.0
# 4                                             NaN         NaN
# ...                                           ...         ...
# 9258                                          NaN        10.0
# 9259                                          2.0         NaN
# 9260                                          NaN         8.0
# 9261                                          NaN         NaN
# 9262                                          NaN         NaN
#
# [9263 rows x 5 columns]

# %% [markdown]
# **Replace blank cells with zero**

# %%
raw_data = pivot.fillna(0)

# %% [markdown]
# **Inspect the new dataset**

# %%
raw_data
# Out:
# category according to process mining  person_id  Consultation  Delivery  \
# 0                                         10429           4.0       0.0
# 1                                         10430          10.0       1.0
# 2                                         10431           9.0       1.0
# 3                                         10432           6.0       0.0
# 4                                         10433           1.0       0.0
# ...                                         ...           ...       ...
# 9258                                      19688           0.0       1.0
# 9259                                      19689           2.0       0.0
# 9260                                      19690          10.0       1.0
# 9261                                      19691           1.0       0.0
# 9262                                      19692           1.0       0.0
#
# category according to process mining  Gynaecology  Obstetrics
# 0                                             3.0         0.0
# 1                                             0.0         8.0
# 2                                             0.0         7.0
# 3                                             0.0         6.0
# 4                                             0.0         0.0
# ...                                           ...         ...
# 9258                                          0.0        10.0
# 9259                                          2.0         0.0
# 9260                                          0.0         8.0
# 9261                                          0.0         0.0
# 9262                                          0.0         0.0
#
# [9263 rows x 5 columns]

# %% [markdown]
# **Leave out the column containing the person_id**

# %%
dataset = raw_data.iloc[:,1:]

# %% [markdown]
# **Inspect the new dataset**

# %%
dataset
# Out:
# category according to process mining  Consultation  Delivery  Gynaecology  \
# 0                                              4.0       0.0          3.0
# 1                                             10.0       1.0          0.0
# 2                                              9.0       1.0          0.0
# 3                                              6.0       0.0          0.0
# 4                                              1.0       0.0          0.0
# ...                                            ...       ...          ...
# 9258                                           0.0       1.0          0.0
# 9259                                           2.0       0.0          2.0
# 9260                                          10.0       1.0          0.0
# 9261                                           1.0       0.0          0.0
# 9262                                           1.0       0.0          0.0
#
# category according to process mining  Obstetrics
# 0                                            0.0
# 1                                            8.0
# 2                                            7.0
# 3                                            6.0
# 4                                            0.0
# ...                                          ...
# 9258                                        10.0
# 9259                                         0.0
# 9260                                         8.0
# 9261                                         0.0
# 9262                                         0.0
#
# [9263 rows x 4 columns]

# %% [markdown]
# **Scale the dataset to make it suitable for this type of machine learning**

# %%
from sklearn import preprocessing 

# scaling the data
data_scaled = preprocessing.scale(dataset)

# %% [markdown]
# **Apply Principal Component Analysis (PCA) on the scaled data**

# %%
from sklearn.decomposition import PCA

# transfer scaled data into PCA components
pca = PCA(n_components=2) 
principalComponents = pca.fit_transform(data_scaled)

# %% [markdown]
# **Create a dataframe of containing the two principal components**

# %%
principalComponents
# Out:
# array([[-0.55340745,  1.48469647],
#        [ 4.25334012, -0.09014134],
#        [ 3.87327703, -0.23625033],
#        ...,
#        [ 4.25334012, -0.09014134],
#        [-0.72820391, -1.03823276],
#        [-0.72820391, -1.03823276]])

# %%
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2'])
principalDf
# Out:
#       principal component 1  principal component 2
# 0                 -0.553407               1.484696
# 1                  4.253340              -0.090141
# 2                  3.873277              -0.236250
# 3                  1.381443              -0.323222
# 4                 -0.728204              -1.038233
# ...                     ...                    ...
# 9258               2.964688              -1.737644
# 9259              -0.782404               0.482077
# 9260               4.253340              -0.090141
# 9261              -0.728204              -1.038233
# 9262              -0.728204              -1.038233
#
# [9263 rows x 2 columns]

# %% [markdown]
# **Evaluate the variance that is explained by PCA in our dataset**

# %%
pca.explained_variance_ratio_
# Out:
# array([0.53844823, 0.28168063])

# %% [markdown]
# **Visualize the dataset along the two principal components in a scatterplot**

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 

plt.scatter(principalComponents[:,0],principalComponents[:,1])
plt.xlabel('principal component 1')
plt.ylabel('principal component 2')
plt.show()

# %% [markdown]
# **Combine PCA with K-means clustering**

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(4)
kmeans.fit(principalComponents)
clusters_new = principalDf.copy()
clusters_new['cluster_pred'] = kmeans.fit_predict(principalComponents)

# %% [markdown]
# **Visualize PCA & K-Means**

# %%
plt.scatter(clusters_new['principal component 1'],clusters_new['principal component 2'], c=clusters_new['cluster_pred']
,cmap='rainbow')
plt.xlabel('principal component 1')
plt.ylabel('principal component 2')
# Out:
# Text(0, 0.5, 'principal component 2')

# %% [markdown]
# **Link the results from K-means clustering back to the tidy dataset**

# %%
identified_clusters = kmeans.fit_predict(data_scaled) 
data_with_clusters = raw_data.copy()
data_with_clusters['Cluster'] = identified_clusters
data_with_clusters
# Out:
# category according to process mining  person_id  Consultation  Delivery  \
# 0                                         10429           4.0       0.0
# 1                                         10430          10.0       1.0
# 2                                         10431           9.0       1.0
# 3                                         10432           6.0       0.0
# 4                                         10433           1.0       0.0
# ...                                         ...           ...       ...
# 9258                                      19688           0.0       1.0
# 9259                                      19689           2.0       0.0
# 9260                                      19690          10.0       1.0
# 9261                                      19691           1.0       0.0
# 9262                                      19692           1.0       0.0
#
# category according to process mining  Gynaecology  Obstetrics  Cluster
# 0                                             3.0         0.0        0
# 1                                             0.0         8.0        2
# 2                                             0.0         7.0        2
# 3                                             0.0         6.0        3
# 4                                             0.0         0.0        3
# ...                                           ...         ...      ...
# 9258                                          0.0        10.0        1
# 9259                                          2.0         0.0        0
# 9260                                          0.0         8.0        2
# 9261                                          0.0         0.0        3
# 9262                                          0.0         0.0        3
#
# [9263 rows x 6 columns]

# %% [markdown]
# **Add the metric 'Distance from closest centroid' obtained from k-means clustering**

# %%
X_dist = kmeans.transform(data_scaled)**2
alldistances = kmeans.fit_transform(data_scaled)
totalDistance = np.min(alldistances, axis=1).round(2)
data_with_distance = data_with_clusters.copy()
data_with_distance['Distance_from_nearest_cluster'] = totalDistance
data_with_distance
# Out:
# category according to process mining  person_id  Consultation  Delivery  \
# 0                                         10429           4.0       0.0
# 1                                         10430          10.0       1.0
# 2                                         10431           9.0       1.0
# 3                                         10432           6.0       0.0
# 4                                         10433           1.0       0.0
# ...                                         ...           ...       ...
# 9258                                      19688           0.0       1.0
# 9259                                      19689           2.0       0.0
# 9260                                      19690          10.0       1.0
# 9261                                      19691           1.0       0.0
# 9262                                      19692           1.0       0.0
#
# category according to process mining  Gynaecology  Obstetrics  Cluster  \
# 0                                             3.0         0.0        0
# 1                                             0.0         8.0        2
# 2                                             0.0         7.0        2
# 3                                             0.0         6.0        3
# 4                                             0.0         0.0        3
# ...                                           ...         ...      ...
# 9258                                          0.0        10.0        1
# 9259                                          2.0         0.0        0
# 9260                                          0.0         8.0        2
# 9261                                          0.0         0.0        3
# 9262                                          0.0         0.0        3
#
# category according to process mining  Distance_from_nearest_cluster
# 0                                                              0.21
# 1                                                              0.68
# 2                                                              0.96
# 3                                                              2.36
# 4                                                              0.56
# ...                                                             ...
# 9258                                                           2.30
# 9259                                                           0.86
# 9260                                                           0.68
# 9261                                                           0.56
# 9262                                                           0.56
#
# [9263 rows x 7 columns]

# %% [markdown]
# **Merge PCA metrics and k-means clustering metrics with the tidy dataset**

# %%
PCA_kmeans = pd.concat([data_with_distance, principalDf], axis=1)
PCA_kmeans
# Out:
#       person_id  Consultation  Delivery  Gynaecology  Obstetrics  Cluster  \
# 0         10429           4.0       0.0          3.0         0.0        0
# 1         10430          10.0       1.0          0.0         8.0        2
# 2         10431           9.0       1.0          0.0         7.0        2
# 3         10432           6.0       0.0          0.0         6.0        3
# 4         10433           1.0       0.0          0.0         0.0        3
# ...         ...           ...       ...          ...         ...      ...
# 9258      19688           0.0       1.0          0.0        10.0        1
# 9259      19689           2.0       0.0          2.0         0.0        0
# 9260      19690          10.0       1.0          0.0         8.0        2
# 9261      19691           1.0       0.0          0.0         0.0        3
# 9262      19692           1.0       0.0          0.0         0.0        3
#
#       Distance_from_nearest_cluster  principal component 1  \
# 0                              0.21              -0.553407
# 1                              0.68               4.253340
# 2                              0.96               3.873277
# 3                              2.36               1.381443
# 4                              0.56              -0.728204
# ...                             ...                    ...
# 9258                           2.30               2.964688
# 9259                           0.86              -0.782404
# 9260                           0.68               4.253340
# 9261                           0.56              -0.728204
# 9262                           0.56              -0.728204
#
#       principal component 2
# 0                  1.484696
# 1                 -0.090141
# 2                 -0.236250
# 3                 -0.323222
# 4                 -1.038233
# ...                     ...
# 9258              -1.737644
# 9259               0.482077
# 9260              -0.090141
# 9261              -1.038233
# 9262              -1.038233
#
# [9263 rows x 9 columns]

# %%
PCA_kmeans.columns
# Out:
# Index(['person_id', 'Consultation', 'Delivery', 'Gynaecology', 'Obstetrics',
#        'Cluster', 'Distance_from_nearest_cluster', 'principal component 1',
#        'principal component 2'],
#       dtype='object')

# %% [markdown]
# **Extract the relevant columns**

# %%
metrics_extracted = PCA_kmeans[['person_id','Cluster', 'Distance_from_nearest_cluster', 'principal component 1',
       'principal component 2' ]]
metrics_extracted
# Out:
#       person_id  Cluster  Distance_from_nearest_cluster  \
# 0         10429        0                           0.21
# 1         10430        2                           0.68
# 2         10431        2                           0.96
# 3         10432        3                           2.36
# 4         10433        3                           0.56
# ...         ...      ...                            ...
# 9258      19688        1                           2.30
# 9259      19689        0                           0.86
# 9260      19690        2                           0.68
# 9261      19691        3                           0.56
# 9262      19692        3                           0.56
#
#       principal component 1  principal component 2
# 0                 -0.553407               1.484696
# 1                  4.253340              -0.090141
# 2                  3.873277              -0.236250
# 3                  1.381443              -0.323222
# 4                 -0.728204              -1.038233
# ...                     ...                    ...
# 9258               2.964688              -1.737644
# 9259              -0.782404               0.482077
# 9260               4.253340              -0.090141
# 9261              -0.728204              -1.038233
# 9262              -0.728204              -1.038233
#
# [9263 rows x 5 columns]

# %% [markdown]
# **Merge the extracted metrics with the original dataset**

# %%
Final_data = pd.merge(merged, metrics_extracted, on= 'person_id')
Final_data
# Out:
#        person_id procedure_date  procedure_concept_id          concept_name_x  \
# 0          11248         8/3/20               2004407    Amputation of cervix
# 1          11248        7/26/20              40379574  Follow-up consultation
# 2          11248         9/1/20              40379574  Follow-up consultation
# 3          11874         4/6/20               2004407    Amputation of cervix
# 4          11874        2/22/20               2110301   Curettage, postpartum
# ...          ...            ...                   ...                     ...
# 52188      17159        1/10/20              45890386     Abortion Procedures
# 52189      17983         9/1/19              45890386     Abortion Procedures
# 52190      18761        9/19/20              45890386     Abortion Procedures
# 52191      18772        9/15/19              45890386     Abortion Procedures
# 52192      19259        4/30/20              45890386     Abortion Procedures
#
#        amount  total_paid  provider_id                    provider_name  \
# 0           1         839        45192  Baptist Health & Medical Center
# 1           1         234        45192  Baptist Health & Medical Center
# 2           1         234        45192  Baptist Health & Medical Center
# 3           1         839        52356              Boudica Female Care
# 4           1         972        52356              Boudica Female Care
# ...       ...         ...          ...                              ...
# 52188       1        1129         4823   East Westfield Health Services
# 52189       1        1129        45192  Baptist Health & Medical Center
# 52190       1        1129         4823   East Westfield Health Services
# 52191       1        1129        45192  Baptist Health & Medical Center
# 52192       1        1129         4823   East Westfield Health Services
#
#       category according to domain expert  \
# 0                               Procedure
# 1                            Consultation
# 2                            Consultation
# 3                               Procedure
# 4                               Procedure
# ...                                   ...
# 52188                           Procedure
# 52189                           Procedure
# 52190                           Procedure
# 52191                           Procedure
# 52192                           Procedure
#
#       category according to process mining          concept_name_y  Cluster  \
# 0                              Gynaecology    Amputation of cervix        3
# 1                             Consultation  Follow-up consultation        3
# 2                             Consultation  Follow-up consultation        3
# 3                              Gynaecology    Amputation of cervix        0
# 4                              Gynaecology   Curettage, postpartum        0
# ...                                    ...                     ...      ...
# 52188                          Gynaecology     Abortion Procedures        3
# 52189                          Gynaecology     Abortion Procedures        3
# 52190                          Gynaecology     Abortion Procedures        3
# 52191                          Gynaecology     Abortion Procedures        3
# 52192                          Gynaecology     Abortion Procedures        3
#
#        Distance_from_nearest_cluster  principal component 1  \
# 0                               0.42              -0.669938
# 1                               0.42              -0.669938
# 2                               0.42              -0.669938
# 3                               1.16              -1.007337
# 4                               1.16              -1.007337
# ...                              ...                    ...
# 52188                           0.85              -1.011402
# 52189                           0.85              -1.011402
# 52190                           0.85              -1.011402
# 52191                           0.85              -1.011402
# 52192                           0.85              -1.011402
#
#        principal component 2
# 0                  -0.197256
# 1                  -0.197256
# 2                  -0.197256
# 3                   1.840743
# 4                   1.840743
# ...                      ...
# 52188              -0.520543
# 52189              -0.520543
# 52190              -0.520543
# 52191              -0.520543
# 52192              -0.520543
#
# [52193 rows x 15 columns]

# %% [markdown]
# **Export the new dataset to a csv file**

# %%
Final_data.to_csv('OBGYN_with_ML_metrics.csv')
